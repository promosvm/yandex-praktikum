# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Загрузка-и-анализ-исходных-данных" data-toc-modified-id="Загрузка-и-анализ-исходных-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка и анализ исходных данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Изучение-исходных-данных" data-toc-modified-id="Изучение-исходных-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изучение исходных данных</a></span></li><li><span><a href="#Изучение-тренировочной-выборки" data-toc-modified-id="Изучение-тренировочной-выборки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изучение тренировочной выборки</a></span></li><li><span><a href="#Изучение-тестовой-выборки" data-toc-modified-id="Изучение-тестовой-выборки-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изучение тестовой выборки</a></span></li><li><span><a href="#Эффективность-обогащения-чернового-концентрата" data-toc-modified-id="Эффективность-обогащения-чернового-концентрата-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Эффективность обогащения чернового концентрата</a></span></li><li><span><a href="#Анализ-признаков-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков-недоступных-в-тестовой-выборке-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Анализ признаков недоступных в тестовой выборке</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Распределение-размера-гранул" data-toc-modified-id="Распределение-размера-гранул-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение размера гранул</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-SMPE" data-toc-modified-id="Функция-для-вычисления-итоговой-SMPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для вычисления итоговой SMPE</a></span></li><li><span><a href="#Построение-моделей" data-toc-modified-id="Построение-моделей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построение моделей</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Древо-решений" data-toc-modified-id="Древо-решений-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Древо решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Фиктивный-регрессор" data-toc-modified-id="Фиктивный-регрессор-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Фиктивный регрессор</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %%
# %load_ext nb_black

# %% [markdown]
# # Сборный проект - 2

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Построить модель которая должна предсказать коэффициент восстановления золота из золотосодержащей руды

# %% [markdown]
# **План проекта**

# %% [markdown]
# 1. Подготовка даных
#
#    1.1 Открыть файлы и изучить их.
#
#    1.2.Проверить, правильность рассчета эффективности обогащения . Вычислите её на обучающей выборке для признака rougher.output.recovery . Найдите MAE между вашими расчётами и значением признака.
#
#    1.3. Проанализировать  признаки, недоступные в тестовой выборке (Что это за параметры? К какому типу относятся?)
#
#    1.4. Проведение предобработки данных.
#
#
# 2. Анализ данных
#
#    2.1. Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки.
#
#    2.2. Анализ распределения размеров гранул сырья на обучающей и тестовой выборках.
#
#    2.3. Анализ суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
#
# 3. Построение модели
#
#    3.1. Функция для вычисления итоговой sMAPE.
#
#    3.2. Обучение моделей и оценка их качества кросс-валидацией. Выбор лучшей модели и проверка  на тестовой выборке.
#
#    Метрики качества:
#
#      sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
#    Метрика sMAPE вычисляется так:
# ![jupyter](./smape.png)
#
#    Нужно спрогнозировать сразу две величины:
#      - эффективность обогащения чернового концентрата rougher.output.recovery;
#      - эффективность обогащения финального концентрата final.output.recovery.
#
#    Итоговая метрика складывается из двух величин:
# ![image.png](./sumsmape.png)

# %% [markdown]
# ## Загрузка и анализ исходных данных

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Загрузим необходимые бибилиотеки

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import *

from sklearn.ensemble import *

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import *
from sklearn.model_selection import *
from sklearn.tree import *

from sklearn.preprocessing import *

from sklearn.utils import shuffle

# %% [markdown]
# Загрузим df

# %%
try:
    df = pd.read_csv("gold_recovery_full_new.csv")
    df_train = pd.read_csv("gold_recovery_train_new.csv")
    df_test = pd.read_csv("gold_recovery_test_new.csv")
except: # ReadError:
    df = pd.read_csv("/datasets/gold_recovery_full_new.csv")
    df_train = pd.read_csv("/datasets/gold_recovery_train_new.csv")
    df_test = pd.read_csv("/datasets/gold_recovery_test_new.csv")

# %% [markdown]
# Изучим **исходные данные**

# %% [markdown]
# ### Изучение исходных данных

# %%
df.head(5)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# Тренировочная выборка состоит из 87 столбцов и 19439 строк. Столбцы имееют вещественный тип данных. Столбец 'date' имеет тип object. Изменим его на date.

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y/%m/%d %H:%M:%S")

# %% [markdown]
# Посмотрим за какое время представленны данные

# %%
df["date"].min()
# Out:
# Timestamp('2016-01-15 00:00:00')

# %%
df["date"].max()
# Out:
# Timestamp('2018-08-18 10:59:59')

# %%
df["date"].max() - df["date"].min()
# Out:
# Timedelta('946 days 10:59:59')

# %% [markdown]
# Данные представлены за 2,5 года

# %% [markdown]
# Более детально распишем названия столбцов

# %% [markdown]
# ____
# ----**финальная характеристика - продукт**---
#
# 1. final.output.concentrate_ag - концентрат серебра
#
# 2. final.output.concentrate_pb	- концентрат свинца
#
# 3. final.output.concentrate_sol - концентрат соли
#
# 4. final.output.concentrate_au - концентрат золота
#
# 5. final.output.recovery - эффективность обогащения финального концентрата
#
# ----**финальная характеристика - отвальные хвосты**---
#
# 6. final.output.tail_ag -  отвальный хвост серебра
#
# 7. final.output.tail_pb - отвальный хвост свинца
#
# 8. final.output.tail_sol - отвальный хвост соли
#
# 9. final.output.tail_au - отвальный хвост золота
#
# ---
# ----**первичная очистка**---
#
# ---**сырье**---
#
# 10. primary_cleaner.input.sulfate - сульфат
#
# 11. primary_cleaner.input.depressant - флотационный агент - депрессант (силикат натрия)
#
# 12. primary_cleaner.input.feed_size -  размер гранул сырья
#
# 13. primary_cleaner.input.xanthate  - ксантогенат (промотер, или активатор флотации)
#
# ---**продукт**---
#
# 14. primary_cleaner.output.concentrate_ag - концентрат серебра
#
# 15. primary_cleaner.output.concentrate_pb - концентрат свинца
#
# 16. primary_cleaner.output.concentrate_sol- концентрат соли
#
# 17. primary_cleaner.output.concentrate_au - концентрат золота
#
# ---**отвальные хвосты**---
#
# 18. primary_cleaner.output.tail_ag - отвальный хвост серебра
#
# 19.  primary_cleaner.output.tail_pb - отвальный хвост свинца
#
# 20.  primary_cleaner.output.tail_sol - отвальный хвост соли
#
# 21.  primary_cleaner.output.tail_au - отвальный хвост золота
#
# ---**параметры, характеризующие флотационную установку при первичной очистке**---
#
#
# 22. primary_cleaner.state.floatbank8_a_air - воздух уровень а
#
# 23. primary_cleaner.state.floatbank8_a_level - уровень а
#
# 24. primary_cleaner.state.floatbank8_b_air - воздух уровень b
#
# 25. primary_cleaner.state.floatbank8_b_level - уровень b
#
# 26. primary_cleaner.state.floatbank8_c_air - воздух уровень с
#
# 27. primary_cleaner.state.floatbank8_c_level - уровень с
#
# 28. primary_cleaner.state.floatbank8_d_air- воздух уровень d
#
# 29. primary_cleaner.state.floatbank8_d_level- уровень d
#
# ___
# ---**Флотация**---
#
# __расчётные характеристики__
#
# 30. rougher.calculation.sulfate_to_au_concentrate - переход сульфата к золотому концентрату
#
# 31. rougher.calculation.floatbank10_sulfate_to_au_feed - расчетные параметры, характеризующие флотационную установку при переходе сульфата к золоту
#
# 32.  rougher.calculation.floatbank11_sulfate_to_au_feed  - расчетные параметры, характеризующие флотационную установку при переходе сульфата к золоту
#
# 33.  rougher.calculation.au_pb_ratio - расчетные параметры, характеризующие  отношение золота к свинцу
#
# ---**сырье**---
#
# 34.  rougher.input.feed_ag - подача серебра
#
# 35.  rougher.input.feed_pb - подача свинца
#
# 36.  rougher.input.feed_rate  - интенсивность подачи
#
# 37.  rougher.input.feed_size - размер подачи
#
# 38.  rougher.input.feed_sol - подача соли
#
# 39.  rougher.input.feed_au  - подача золота
#
# __флотационная установка - параметры сырья__
#
# 40.  rougher.input.floatbank10_sulfate - флотационные реагенты - сульфат
#
# 41.  rougher.input.floatbank10_xanthate - флотационные реагенты - активатор флотации
#
# 42.  rougher.input.floatbank11_sulfate - флотационные реагенты - сульфат
#
# 43.  rougher.input.floatbank11_xanthate- флотационные реагенты - активатор флотации
#
# ---**продукт**---
#
# 44.  rougher.output.concentrate_ag - концентрат серебра
#
# 45.  rougher.output.concentrate_pb - концентрат свинца
#
# 46.  rougher.output.concentrate_sol- концентрат соли
#
# 47.  rougher.output.concentrate_au- концентрат золота
#
# 48.  rougher.output.recovery - эффективность обогащения
#
# ---**отвальные хвосты**---
#
# 49.  rougher.output.tail_ag - отвальный хвост серебра
#
# 50.  rougher.output.tail_pb - отвальный хвост свинца
#
# 51.  rougher.output.tail_sol - отвальный хвост соли
#
# 52.  rougher.output.tail_au - отвальный хвост золота
#
# ---**параметры, характеризующие флотационную установку при флотации**---
#
# 53.  rougher.state.floatbank10_a_air - воздух уровень а
#
# 54.  rougher.state.floatbank10_a_level - уровень а
#
# 55.  rougher.state.floatbank10_b_air - воздух уровень b
#
# 56.  rougher.state.floatbank10_b_level - уровень b
#
# 57.  rougher.state.floatbank10_c_air - воздух уровень c
#
# 58.  rougher.state.floatbank10_c_level - уровень c
#
# 59.  rougher.state.floatbank10_d_air - воздух уровень d
#
# 60.  rougher.state.floatbank10_d_level - уровень d
#
# 61.  rougher.state.floatbank10_e_air - воздух уровень e
#
# 62.  rougher.state.floatbank10_e_level - уровень e
#
# 63.  rougher.state.floatbank10_f_air - воздух уровень f
#
# 64.  rougher.state.floatbank10_f_level - уровень f
#
#
# ___
#
# ---**Вторичная очистка**---
#
# ---**отвальные хвосты**---
#
# 65.  secondary_cleaner.output.tail_ag - хвосты серебра
#
# 66.  secondary_cleaner.output.tail_pb - хвосты свинца
#
# 67.  secondary_cleaner.output.tail_sol - хвосты соли
#
# 68.  secondary_cleaner.output.tail_au - хвосты золота
#
# ---**параметры, характеризующие флотационную установку при вторичной очистке**---
#
# 69.  secondary_cleaner.state.floatbank2_a_air - воздух уровень а
#
# 70.  secondary_cleaner.state.floatbank2_a_level - уровень а
#
# 71.  secondary_cleaner.state.floatbank2_b_air - воздух уровень b
#
# 72.  secondary_cleaner.state.floatbank2_b_level - уровень b
#
# 73.  secondary_cleaner.state.floatbank3_a_air  - воздух уровень а
#
# 74.  secondary_cleaner.state.floatbank3_a_level - уровень а
#
# 75.  secondary_cleaner.state.floatbank3_b_air  - воздух уровень b
#
# 76.  secondary_cleaner.state.floatbank3_b_level -  уровень b
#
# 77.  secondary_cleaner.state.floatbank4_a_air - воздух уровень а
#
# 78.  secondary_cleaner.state.floatbank4_a_level - уровень а
#
# 79.  secondary_cleaner.state.floatbank4_b_air - воздух уровень b
#
# 80.  secondary_cleaner.state.floatbank4_b_level - уровень b
#
# 81.  secondary_cleaner.state.floatbank5_a_air - воздух уровень а
#
# 82.  secondary_cleaner.state.floatbank5_a_level - уровень а
#
# 83.  secondary_cleaner.state.floatbank5_b_air - воздух уровень b
#
# 84.  secondary_cleaner.state.floatbank5_b_level - уровень b
#
# 85.  secondary_cleaner.state.floatbank6_a_air - воздух уровень а
#
# 86.  secondary_cleaner.state.floatbank6_a_level - уровень а

# %% [markdown]
# Проверим пропущенные значения

# %%
# Сделаем ограничение на количество выводимых рядов - 100
pd.set_option("display.max_rows", 100)

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# secondary_cleaner.output.tail_sol                     0.089922
# rougher.input.floatbank11_xanthate                    0.023304
# rougher.state.floatbank10_e_air                       0.022429
# primary_cleaner.output.concentrate_sol                0.019034
# secondary_cleaner.state.floatbank2_a_air              0.011317
# final.output.concentrate_sol                          0.010854
# rougher.input.feed_size                               0.007459
# primary_cleaner.output.concentrate_pb                 0.005967
# primary_cleaner.input.xanthate                        0.005350
# final.output.tail_pb                                  0.005196
# rougher.input.feed_pb                                 0.005144
# rougher.input.feed_sol                                0.005093
# primary_cleaner.output.tail_sol                       0.003189
# rougher.input.floatbank11_sulfate                     0.002263
# primary_cleaner.input.depressant                      0.001903
# ...

# %% [markdown]
#  Мы имеем пропущенные данные, причем доля пропущенных значений не высока и колеблится в пределах от 0.089922 до 0.000051. Заменим пропущенные значения, используя стратегию ближайших значений - ffill, так как данные в нашей выборке связаны с датой и временем.

# %%
df = df.fillna(method="ffill")

# %% [markdown]
# Проверим на наличие дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# Посмотрим на корреляционную зависимость между final.output.concentrate_au - нашей целевой переменной и отстальными признаками.

# %%
df.corr().style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Можно проследить слабую обратную корреляцию между final.output.concentrate_au и финальным концентратом серебра, и прямую слабую корреляцию между final.output.concentrate_au и финальными концентратами свинца, соли, концентратом золота при первичной очистки.

# %% [markdown]
# ### Изучение тренировочной выборки

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# Тренировочная выборка состоит из 87 столбцов и 14149 строк. Столбцы имееют вещественный тип данных. Столбец 'date' имеет тип object. Изменим его на date.

# %%
df_train["date"] = pd.to_datetime(df_train["date"], format="%Y/%m/%d %H:%M:%S")

# %% [markdown]
# Проверим пропущенные значения

# %%
df_train.isna().mean().sort_values(ascending=False)
# Out:
# secondary_cleaner.output.tail_sol                     0.113436
# rougher.state.floatbank10_e_air                       0.030815
# rougher.input.floatbank11_xanthate                    0.030249
# primary_cleaner.output.concentrate_sol                0.020213
# secondary_cleaner.state.floatbank2_a_air              0.015337
# final.output.concentrate_sol                          0.014913
# rougher.input.feed_size                               0.010177
# primary_cleaner.input.xanthate                        0.007068
# rougher.input.feed_pb                                 0.007068
# final.output.tail_pb                                  0.007068
# primary_cleaner.output.concentrate_pb                 0.006078
# rougher.input.feed_sol                                0.005513
# primary_cleaner.output.tail_sol                       0.003251
# rougher.input.floatbank11_sulfate                     0.002544
# primary_cleaner.input.depressant                      0.002262
# ...

# %% [markdown]
#  Мы имеем пропущенные данные, причем доля пропущенных значений не высока и колеблится в пределах от  0.113436 до 0.000071. Заменим пропущенные значения, используя стратегию ближайших значений - ffill, так как данные в нашей выборке связаны с датой и временем.

# %%
df_train = df_train.fillna(method="ffill")

# %% [markdown]
# Проверим что все ОК

# %%
df_train.isna().sum()
# Out:
# date                                                  0
# final.output.concentrate_ag                           0
# final.output.concentrate_pb                           0
# final.output.concentrate_sol                          0
# final.output.concentrate_au                           0
# final.output.recovery                                 0
# final.output.tail_ag                                  0
# final.output.tail_pb                                  0
# final.output.tail_sol                                 0
# final.output.tail_au                                  0
# primary_cleaner.input.sulfate                         0
# primary_cleaner.input.depressant                      0
# primary_cleaner.input.feed_size                       0
# primary_cleaner.input.xanthate                        0
# primary_cleaner.output.concentrate_ag                 0
# primary_cleaner.output.concentrate_pb                 0
# primary_cleaner.output.concentrate_sol                0
# ...

# %% [markdown]
# Проверим на наличие дубликатов

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# ### Изучение тестовой выборки

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# Тренировочная выборка состоит из 53 столбцов и 5290 строк. Столбцы имееют вещественный тип данных. Столбец 'date' имеет тип object. Изменим его на date.

# %%
df_test["date"] = pd.to_datetime(df_test["date"], format="%Y/%m/%d %H:%M:%S")

# %%
df_test.isna().mean().sort_values(ascending=False)
# Out:
# rougher.input.floatbank11_xanthate            0.004726
# rougher.input.feed_sol                        0.003970
# secondary_cleaner.state.floatbank3_a_air      0.001701
# rougher.input.floatbank11_sulfate             0.001512
# primary_cleaner.input.depressant              0.000945
# rougher.input.floatbank10_sulfate             0.000945
# primary_cleaner.input.xanthate                0.000756
# primary_cleaner.input.sulfate                 0.000756
# rougher.input.feed_rate                       0.000567
# secondary_cleaner.state.floatbank2_a_air      0.000567
# secondary_cleaner.state.floatbank2_b_air      0.000378
# rougher.input.feed_size                       0.000189
# secondary_cleaner.state.floatbank2_b_level    0.000000
# rougher.state.floatbank10_f_level             0.000000
# rougher.state.floatbank10_f_air               0.000000
# secondary_cleaner.state.floatbank3_a_level    0.000000
# secondary_cleaner.state.floatbank2_a_level    0.000000
# ...

# %% [markdown]
#  Мы имеем пропущенные данные, причем доля пропущенных значений не высока и колеблится в пределах от  0.004726 до 0.000189. Так-же пропущенные значения, заменим ближайшими.

# %%
df_test = df_test.merge(
    df[["final.output.recovery", "rougher.output.recovery"]],
    how="left",
    left_index=True,
    right_index=True,
)

# %%
df_test = df_test.fillna(method="ffill")

# %% [markdown]
# Проверим что все ОК

# %%
df_test.isna().sum()
# Out:
# date                                          0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# ...

# %% [markdown]
# Проверим на наличие дубликатов

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# ###  Эффективность обогащения чернового концентрата

# %% [markdown]
# Рассчитаем эффективность обогащения чернового концентрата rougher.output.recovery из обучающей выборки.

# %%
rougher_output_recovery_calc = (
    100
    * (
        df_train["rougher.output.concentrate_au"]
        * (df_train["rougher.input.feed_au"] - df_train["rougher.output.tail_au"])
    )
    / (
        df_train["rougher.input.feed_au"]
        * (
            df_train["rougher.output.concentrate_au"]
            - df_train["rougher.output.tail_au"]
        )
    )
)
df_output_rougher = pd.DataFrame(
    {
        "output_recovery": df_train["rougher.output.recovery"],
        "calc": rougher_output_recovery_calc,
    }
)
MAE = mean_absolute_error(
    df_output_rougher["output_recovery"], df_output_rougher["calc"]
)
print(f"Абсолютная средняя ошибка = {MAE}")
# Out:
# Абсолютная средняя ошибка = 1.1131451184435918e-14

# %% [markdown]
# MAE имеет очень малое отклонение - это значит, что расчетное значение rougher.output.recovery совпадает с данными из столбца.

# %% [markdown]
# ### Анализ признаков недоступных в тестовой выборке

# %% [markdown]
# Проанализируйте функции, недоступные в тестовом наборе. Что это за параметры? Каков их тип?

# %%
df_types = df.dtypes.reset_index()
df_types.columns = ["name", "type"]
all_columns = pd.Series(
    list(set(df.columns).union(set(df_train.columns).union(set(df_test.columns))))
)
df_temp = pd.DataFrame({"name": all_columns}).merge(df_types).sort_values(by="name")
df_temp["df"] = np.vectorize(lambda x: int(x in df.columns))(df_temp["name"].values)
df_temp["train"] = np.vectorize(lambda x: int(x in df_train.columns))(
    df_temp["name"].values
)
df_temp["test"] = np.vectorize(lambda x: int(x in df_test.columns))(
    df_temp["name"].values
)
df_temp[df_temp["test"] == 0]
# Out:
#                                                  name     type  df  train  \
# 59                        final.output.concentrate_ag  float64   1      1
# 61                        final.output.concentrate_au  float64   1      1
# 52                        final.output.concentrate_pb  float64   1      1
# 18                       final.output.concentrate_sol  float64   1      1
# 79                               final.output.tail_ag  float64   1      1
# 35                               final.output.tail_au  float64   1      1
# 56                               final.output.tail_pb  float64   1      1
# 73                              final.output.tail_sol  float64   1      1
# 43              primary_cleaner.output.concentrate_ag  float64   1      1
# 7               primary_cleaner.output.concentrate_au  float64   1      1
# 84              primary_cleaner.output.concentrate_pb  float64   1      1
# 26             primary_cleaner.output.concentrate_sol  float64   1      1
# ...

# %% [markdown]
# Из 34 пропущенных признаков 30 относятся к параметрам продукта и только 4 к расчетным характеристикам. Пропущенные  значения получаются в результате технологического процесса - онлайн метрики. Остальные столбцы известны - офлайн метрики.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Данные представлены за 2,5 года.
# 2. В данных есть пропущенные значения, причем доля пропущенных значений не высока и колеблится в пределах до 12 процентов и ниже. Пропущенные значения, заменены ближайшими значениями используя стратегию ближайших значений - ffill, так как данные в нашей выборке связаны с датой и временем.
# 3. Можно проследить слабую обратную корреляцию между final.output.concentrate_au и финальным концентратом серебра, и прямую  слабую корреляцию между final.output.concentrate_au и финальными концентратами свинца, соли, концентратом золота при первичной очистке.
# 4. Абсолютная средняя ошибка равна 1.1231825127768126e-14 - расчетное значение rougher.output.recovery совпадает с данными из столбца.
# 5. В тестовой выборке отсутсвует 34  значения которые есть в тренировочной и исходной выборке. 30 значений относятся к параметрам продукта, 4 к расчетным характеристикам. Пропущенные  значения (онлайн метрики) получаются в результате технологического процесса. Остальные столбцы известны - офлайн метрики.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
print("Концентрация до флотации")
print(
    "Концентрация Серебра:{: 0.2f},Свинца:{: 0.2f},Золота:{: 0.2f}".format(
        df["rougher.input.feed_ag"].mean(),
        df["rougher.input.feed_pb"].mean(),
        df["rougher.input.feed_au"].mean(),
    )
)

print()
print("Первичная очистка")
print(
    "Концентрация Серебра:{: 0.2f},Свинца:{: 0.2f},Золота:{: 0.2f}".format(
        df["primary_cleaner.output.concentrate_ag"].mean(),
        df["primary_cleaner.output.concentrate_pb"].mean(),
        df["primary_cleaner.output.concentrate_au"].mean(),
    )
)
print()
print("Флотация")
print(
    "Коцентрация Серебра:{: 0.2f},Свинца:{: 0.2f},Золота:{: 0.2f}".format(
        df["rougher.output.concentrate_ag"].mean(),
        df["rougher.output.concentrate_pb"].mean(),
        df["rougher.output.concentrate_au"].mean(),
    )
)
print()
print("Вторичная очистка")
print(
    "Концентрация Серебра:{: 0.2f},Свинца:{: 0.2f},Золота:{: 0.2f}".format(
        df["final.output.concentrate_ag"].mean(),
        df["final.output.concentrate_pb"].mean(),
        df["final.output.concentrate_au"].mean(),
    )
)
# Out:
# Концентрация до флотации
# Концентрация Серебра: 8.79,Свинца: 3.59,Золота: 8.27
#
# Первичная очистка
# Концентрация Серебра: 8.44,Свинца: 9.81,Золота: 32.12
#
# Флотация
# Коцентрация Серебра: 11.99,Свинца: 7.61,Золота: 19.77
#
# Вторичная очистка
# Концентрация Серебра: 5.17,Свинца: 9.98,Золота: 44.08

# %% [markdown]
# Из представленных данных видно, что до флотации концентрация золота самая маленькая, потом после первичной обработки, концентрация золота в продукте возрастает, после проведения флотации концентрация золота уменьшается, концентрация серебра возростает. После проведения вторичной очистки концентрация золота возростает.

# %% [markdown]
# Посмотрим на графическое распределение

# %%
plt.figure(figsize=[15, 10])

sns.kdeplot(
    df_train["rougher.input.feed_au"], label="Начальная концентрация",
)

sns.kdeplot(
    df_train["primary_cleaner.output.concentrate_au"], label="Первичная очистка",
)

sns.kdeplot(df_train["rougher.output.concentrate_au"], label="Флотация")

sns.kdeplot(df_train["final.output.concentrate_au"], label="Вторичная очистка")
plt.grid()
plt.xlabel("Концентрация золота")
plt.ylabel("Количество")

plt.legend(loc="upper right", fontsize="x-large")

plt.title("Гистограмма распределения концентрации золота")
plt.show()

# %% [markdown]
# Мы наблюдаем, что после вторичной очистки распределение принимает более вытянутую форму, с большшими пиковыми значениями, что может говорить нам, о эффективности проведения флотации, особенно на заключительном этапе очистки.

# %%
plt.figure(figsize=[15, 10])

sns.kdeplot(
    df_train["rougher.input.feed_ag"], label="Начальная концентрация",
)

sns.kdeplot(
    df_train["primary_cleaner.output.concentrate_ag"], label="Первичная очистка",
)

sns.kdeplot(df_train["rougher.output.concentrate_ag"], label="Флотация")


sns.kdeplot(df_train["final.output.concentrate_ag"], label="Вторичная очистка")
plt.grid()
plt.xlabel("Концентрация серебра")
plt.ylabel("Количество")

plt.legend(loc="upper right", fontsize="x-large")

plt.title("Гистограмма распределения концентрации серебра")
plt.show()

# %% [markdown]
# Из распределения видно, что большая концентрация серебра наблюдается при проведении флотации, в ходе вторичной очистки, концентрация серебра уменьшается, распределение принимает вытяннутую вверх форму.

# %%
plt.figure(figsize=[15, 10])

sns.kdeplot(
    df_train["rougher.input.feed_pb"], label="Начальная концентрация",
)

sns.kdeplot(
    df_train["primary_cleaner.output.concentrate_pb"], label="Первичная очистка",
)

sns.kdeplot(df_train["rougher.output.concentrate_pb"], label="Флотация")


sns.kdeplot(df_train["final.output.concentrate_pb"], label="Вторичная очистка")
plt.grid()
plt.xlabel("Концентрация свинца")
plt.ylabel("Количество результатов")

plt.legend(loc="upper right", fontsize="x-large")

plt.title("Гистограмма распределения концентрации свинца")
plt.show()

# %% [markdown]
# Концентрация свинца снижается с этапа первичной очистки до этапа флотации. И потом опять увеличивается до значений близких к первичной очистке. Это связано с химическим процесами очищения золота. При использование азотнокислого выщелачивания в концентрате образуется много сульфата свинца.

# %% [markdown]
# Из графиков видно, что много значений в 0. Эти значения очень далики от общего распределения, это выбросы, в тренировочной и тестовой выборке их следует удалить.

# %%
df_train = df_train.drop(index = df_train[df_train["rougher.input.feed_au"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.input.feed_ag"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.input.feed_pb"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.input.feed_sol"] < 1].index,
                               axis = 0)


df_train = df_train.drop(index = df_train[df_train["rougher.output.concentrate_au"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.output.concentrate_ag"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.output.concentrate_pb"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["rougher.output.concentrate_sol"] < 1].index,
                               axis = 0)

df_train = df_train.drop(index = df_train[df_train["primary_cleaner.output.concentrate_au"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["primary_cleaner.output.concentrate_ag"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["primary_cleaner.output.concentrate_pb"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["primary_cleaner.output.concentrate_sol"] < 1].index,
                               axis = 0)

df_train = df_train.drop(index = df_train[df_train["final.output.concentrate_au"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["final.output.concentrate_ag"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["final.output.concentrate_pb"] < 1].index,
                               axis = 0)
df_train = df_train.drop(index = df_train[df_train["final.output.concentrate_sol"] < 1].index,
                               axis = 0)

# %% [markdown]
# ### Распределение размера гранул

# %%
plt.figure(figsize=[15, 10])
for frame, name in zip(
    [df_train, df_test], ["Тренировочная выборка", "Тестовая выборка"]
):
    sns.distplot(frame["rougher.input.feed_size"], hist=False, kde=True, label=name)

plt.grid()
plt.xlabel("Размер гранул")
plt.ylabel("Колличество гранул")

plt.legend(loc="upper right", fontsize="x-large")

plt.title("Гистограмма распределения размера гранул")
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Мы можем видеть, что распределения отличаются но несильно. В тренировочной выборке преобладают значения около порога 50 и выше, в то же время как в тестовой выборке достаточно большое количество объектов сконцентрированы до порога 50.

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях

# %%
primary_output_concentrate_sum_train = (
    df_train["rougher.input.feed_au"]
    + df_train["rougher.input.feed_ag"]
    + df_train["rougher.input.feed_pb"]
    + df_train["rougher.input.feed_sol"]
)
print(
    f"Суммарное значение концентрации всех веществ в сырье {primary_output_concentrate_sum_train.sum()}"
)
rougher_output_concentrate_sum_train = (
    df_train["rougher.output.concentrate_au"]
    + df_train["rougher.output.concentrate_ag"]
    + df_train["rougher.output.concentrate_pb"]
    + df_train["rougher.output.concentrate_sol"]
)
print(
    f"Суммарное значение концентрации всех веществ в черновом концентрате {rougher_output_concentrate_sum_train.sum()}"
)

final_output_concentrate_sum_train = (
    df_train["final.output.concentrate_au"]
    + df_train["final.output.concentrate_ag"]
    + df_train["final.output.concentrate_pb"]
    + df_train["final.output.concentrate_sol"]
)
print(
    f"Суммарное значение концентрации всех веществ в финальном концентрате {final_output_concentrate_sum_train.sum()}"
)
# Out:
# Суммарное значение концентрации всех веществ в сырье 751178.0465465173
# Суммарное значение концентрации всех веществ в черновом концентрате 915279.8285761836
# Суммарное значение концентрации всех веществ в финальном концентрате 916021.7402665626

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Всё верно!</font>

# %%
plt.figure(figsize=[15, 10])

sns.kdeplot(
    final_output_concentrate_sum_train, label="Финальный концентрат",
)
sns.kdeplot(primary_output_concentrate_sum_train, label="Сырье")
sns.kdeplot(rougher_output_concentrate_sum_train, label="Черновой концентрант")

plt.xlabel("Суммарная концентраця")
plt.ylabel("Количество")

plt.legend(loc="upper left", fontsize="x-large")

plt.title("Суммарная концентрация всех веществ на разных стадиях")
plt.show()

# %% [markdown]
# Из распределени видно, что сумарная концентрация всех веществ увеличивается при проведении этапов флотации, но что если при проведении первого этапа очистки и самой флотации колличество веществ увеличилось значительно, то между   флотацией и вторичной очитской колличество веществ существенно не изменилось.

# %% [markdown]
# Интересные преобразования происходят при очитске чернового концентрата. На графике видно, что пиковые значения одниковые суммарной концентрации всех веществ в черновом концентрате совподает с пиковыми значениями суммарных концентраций всех веществ в финальном концентрате. Но колличественное значение разные и отличаются друг от друга более чем в два раза.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Из представленных данных видно, что до флотации концентрация золота самая маленькая, потом после первичной обработки, концентрация золота в продукте возрастает, после проведения флотации концентрация золота уменьшается, концентрация серебра возростает. После проведения вторичной очистки концентрация золота возростает.
#
# 2. Различия в распределении размера гранул в тестовой и тренировочной выборке но велико. В тренировочной выборке преобладают значения около порога 50 и выше, в то же время как в тестовой выборке достаточно большое количество объектов сконцентрированы до порога 50.
#
# 3. Сумарная концентрация всех веществ увеличивается при проведении этапов флотации, но что если при проведении первого этапа очистки и самой флотации колличество веществ увеличилось значительно, то при проведении флотации и вторичной очитски колличество веществ существенно не изменилось.

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### Функция для вычисления итоговой SMPE

# %%
def smape(y_true, y_pred):
    frac = np.divide(np.abs(y_true - y_pred), (np.abs(y_true) + np.abs(y_pred)) / 2)
    return (np.average(frac, axis=0)) * 100

# %%
def smape_final(y_true, y_pred):
    smape_out_rougher = smape(
        y_true[target.index("rougher.output.recovery")],
        y_pred[target.index("rougher.output.recovery")],
    )
    smape_out_final = smape(
        y_true[target.index("final.output.recovery")],
        y_pred[target.index("final.output.recovery")],
    )
    return 0.25 * smape_out_rougher + 0.75 * smape_out_final

# %% [markdown]
# ### Построение моделей

# %%
for df in [df, df_train, df_test]:
    if "date" in df.columns:
        df.set_index("date", inplace=True)

# %%
df_test = df_test.merge(
    df[["final.output.recovery", "rougher.output.recovery"]],
    how="left",
    left_index=True,
    right_index=True,
)

# %%
# код ревьюера
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5290 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 56 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5290 non-null   float64
#  1   primary_cleaner.input.depressant            5290 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5290 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
# ...

# %%
df_test = df_test.merge(
    df[["final.output.recovery", "rougher.output.recovery"]],
    how="left",
    left_index=True,
    right_index=True,
)

# %% [markdown]
# Выберем целевой признак

# %%
target = ["rougher.output.recovery", "final.output.recovery"]
features = list(
    set(df_train.columns).intersection(set(df_test.columns)).difference(set(target))
)

# %% [markdown]
# Промасштабируем признаки

# %%
scaler = MinMaxScaler()
scaler.fit(df_train[features])
df_train[features] = scaler.transform(df_train[features])
pd.options.mode.chained_assignment = None

# %%
X_train, X_test = df_train[features].values, df_test[features].values
y_train, y_test = df_train[target].values, df_test[target].values

# %% [markdown]
# Перед нами стоит задача регресии. Выберем следующие модели для обучения:
# - Линейная регрессия
# - DecisionTreeRegressor
# - RandomForestRegressor
# - Фиктивный регрессор
#
# Выполним поиск лучшей модели для предсказаний

# %% [markdown]
# ### Линейная регрессия

# %%
smape_score = make_scorer(smape_final, greater_is_better=False)

# %%
lr = LinearRegression(cross_val_score).fit(X_train, y_train)
scores_lr = cross_val_score(lr, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_lr.mean())
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass fit_intercept=<function cross_val_score at 0x7f5ba3851550> as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# mean smape: -4.250046229839549

# %% [markdown]
# ### Древо решений

# %%
random_state = 42
params = {"min_samples_split": range(2, 10, 2), "max_depth": range(4, 8, 2)}
g_cv = GridSearchCV(
    DecisionTreeRegressor(random_state=random_state),
    param_grid=params,
    scoring=smape_score,
    cv=5,
    refit=True,
)
model_g_cv = g_cv.fit(X_train, y_train)
best_params = g_cv.best_params_
scores_dtr = cross_val_score(g_cv, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_dtr.mean())
# Out:
# mean smape: -6.4342944785027045

# %% [markdown]
# ### Случайный лес

# %%
params = {"min_samples_split": range(2, 6, 2)}
rf_cv = GridSearchCV(
    RandomForestRegressor(random_state=random_state, n_jobs=-1),
    param_grid=params,
    scoring=smape_score,
    cv=5,
    refit=True,
)
model_rf_cv = rf_cv.fit(X_train, y_train)
best_params = rf_cv.best_params_

# %%
scores_rfr = cross_val_score(rf_cv, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_rfr.mean())

# %%
y_pred = model_rf_cv.predict(X_test)
print("smape:", smape_final(y_test, y_pred))

# %% [markdown]
# На тестовых данных симметричное среднее абсолютное процентное отклонение $\approx$ 5.95

# %% [markdown]
# ### Фиктивный регрессор

# %%
dm = DummyRegressor(strategy="mean").fit(X_train, y_train)
y_pred = dm.predict(X_test)
print("smape:", smape_final(y_test, y_pred))

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лучше всех себя показал **Фиктивный регрессор**  (симметричное среднее абсолютное процентное отклонение $\approx$ 3.82)
#
# 3) Древо решений: симметричное среднее абсолютное процентное отклонение $\approx$ -6.43
#
# 1) Линейная регрессия: симметричное среднее абсолютное процентное отклонение $\approx$ -4.25
#
# 2) Случайный лес: симметричное среднее абсолютное процентное отклонение $\approx$ -4.15

# %% [markdown]
# ## Вывод

# %% [markdown]
# - Из представленных данных видно, что до флотации концентрация золота самая маленькая, после первичной обработки, концентрация золота в продукте возрастает, при проведения флотации концентрация золота уменьшается, концентрация серебра возростает. После проведения вторичной очистки концентрация золота возростает до пиковых значений.
#
# - Различия в распределении размера гранул в тестовой и тренировочной выборке не велико. В тренировочной выборке преобладают значения около  50 и выше, в то же время как в тестовой выборке достаточно большое количество объектов сконцентрированы до 50.
#
# - Сумарная концентрация всех веществ увеличивается при проведении этапов флотации, но что если при проведении первого этапа очистки и самой флотации колличество веществ увеличилось значительно, то при проведении флотации и вторичной очитски колличество веществ существенно не изменилось.
#
# - Можно проследить слабую обратную корреляцию между final.output.concentrate_au и финальным концентратом серебра, и прямую корреляцию между final.output.concentrate_au и финальными концентратами свинца, соли, концентратом золота при первичной очистке.
#
# - Абсолютная средняя ошибка равна 1.1231825127768126e-14, это значит, что расчетное значение rougher.output.recovery совпадает с данными из столбца.
#
# - Фиктивный регрессор показал себя лучшей моделью по сравнению с такими моделями как Линейной регресии, Древо решений, Леса решений. Cимметричное среднее абсолютное процентное отклонение $\approx$ 0.03223
